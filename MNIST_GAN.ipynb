# %% [markdown]
# <a href="https://colab.research.google.com/github/Musbell/MNIST_GAN/blob/master/MNIST_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
from torchvision import datasets
import torchvision.transforms as transforms

# number of subprocesses to use for data loading
num_workers = 0
# How many samples per batch to load
batch_size = 64

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# get the training datasets
train_data = datasets.MNIST(root='data', train=True, download=True, transform=transform)

# prepare data loader
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           num_workers=num_workers)

# %% [markdown]
# **Visualize the data**

# %%
# Obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images.numpy()

# Get one image from the batch
img = np.squeeze(images[0])

fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %% [markdown]
# # **Define a Model**

# %%
import torch.nn as nn
import torch.nn.functional as F

class Discriminator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Discriminator, self).__init__()
        
        # define hidden linear layers
        self.fc1 = nn.Linear(input_size, hidden_dim*4)
        self.fc2 = nn.Linear(hidden_dim*4, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim)
        
        # final fully-connected layer
        self.fc4 = nn.Linear(hidden_dim, output_size)
        
        # dropout layer 
        self.dropout = nn.Dropout(0.3)
        
        
    def forward(self, x):
        # flatten image
        x = x.view(-1, 28*28)
        # all hidden layers
        x = F.leaky_relu(self.fc1(x), 0.2) # (input, negative_slope=0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc3(x), 0.2)
        x = self.dropout(x)
        # final layer
        out = self.fc4(x)

        return out

# %% [markdown]
# # **Generator**

# %%
class Generator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Generator, self).__init__()
        
        # define hidden linear layers
        self.fc1 = nn.Linear(input_size, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim*4)
        
        # final fully-connected layer
        self.fc4 = nn.Linear(hidden_dim*4, output_size)
        
        # dropout layer 
        self.dropout = nn.Dropout(0.3)

    def forward(self, x):
        # all hidden layers
        x = F.leaky_relu(self.fc1(x), 0.2) # (input, negative_slope=0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc3(x), 0.2)
        x = self.dropout(x)
        # final layer with tanh applied
        out = F.tanh(self.fc4(x))

        return out

# %% [markdown]
# # **Model hyperparameters**

# %%
# Discriminator hyperparams

# Size of input image to discriminator (28*28)
input_size = 784
# Size of discriminator output (real or fake)
d_output_size = 1
# Size of last hidden layer in the discriminator
d_hidden_size = 32

# Generator hyperparams

# Size of latent vector to give to generator
z_size = 100
# Size of discriminator output (generated image)
g_output_size = 784
# Size of first hidden layer in the generator
g_hidden_size = 32

# %% [markdown]
# # **Build complete network**

# %%
# instantiate discriminator and generator
D = Discriminator(input_size, d_hidden_size, d_output_size)
G = Generator(z_size, g_hidden_size, g_output_size)

# check that they are as you expect
print(D)
print()
print(G)
# Out:
# Discriminator(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )
#
# Generator(
#   (fc1): Linear(in_features=100, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=784, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %% [markdown]
# # **Discriminator and Generator Losses**

# %%
# Calculate losses
def real_loss(D_out, smooth=False):
  batch_size = D_out.size(0)
  # label smoothing
  if smooth:
    # smooth, real labels = 0.9
    labels = torch.ones(batch_size)*0.9
  else:
    labels = torch.ones(batch_size)  # real labels = 1

  # numerically stable loss
  criterion = nn.BCEWithLogitsLoss()
  # calculate loss
  loss = criterion(D_out.squeeze(), labels)
  return loss

def fake_loss(D_out):
  batch_size = D_out.size(0)
  labels = torch.zeros(batch_size) # fake labels = 0
  criterion = nn.BCEWithLogitsLoss()
  # calculate loss
  loss = criterion(D_out.squeeze(), labels)
  return loss

# %% [markdown]
# # **Optimizers**

# %%
import torch.optim as optim

# Optimizers
lr = 0.002

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr)
g_optimizer = optim.Adam(G.parameters(), lr)

# %% [markdown]
# # **Training**

# %%
import pickle as pkl

# training hyperparams
num_epochs = 100

# keep track of loss and generated, "fake" samples
samples = []
losses = []

print_every = 400

# Get some fixed data for sampling. These are images that are held
# constant throughout training, and allow us to inspect the model's performance
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
D.train()
G.train()

for epoch in range(num_epochs):

  for batch_i, (real_images, _) in enumerate(train_loader):

    batch_size = real_images.size(0)
    ## Important rescaling step ## 
    real_images = real_images*2 - 1  # rescale input images from [0,1) to [-1, 1)

    ### Train the Discriminator ###

    d_optimizer.zero_grad()

    # 1. Train with real images

    # Compute the discriminator losses on real images 
    # smooth the real labels
    D_real = D(real_images)
    d_real_loss = real_loss(D_real, smooth=True)

    # 2. Train with fake images
        
    # Generate fake images
    z = np.random.uniform(-1, 1, size=(batch_size, z_size))
    z = torch.from_numpy(z).float()
    fake_images = G(z)

    # Compute the discriminator losses on fake images 
    D_fake = D(fake_images)
    d_fake_loss = fake_loss(D_fake)

    # add up loss and perform backprop
    d_loss = d_real_loss + d_fake_loss
    d_loss.backward()
    d_optimizer.step()


    ### Train the Generator ###
    g_optimizer.zero_grad()

    # 1. Train with fake images and flipped labels
        
    # Generate fake images
    z = np.random.uniform(-1, 1, size=(batch_size, z_size))
    z = torch.from_numpy(z).float()
    fake_images = G(z)

    # Compute the discriminator losses on fake images 
    # using flipped labels!
    D_fake = D(fake_images)
    g_loss = real_loss(D_fake) # use real loss to flip labels

    # perform backprop
    g_loss.backward()
    g_optimizer.step()

    # Print some loss stats
    if batch_i % print_every == 0:
        # print discriminator and generator loss
        print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                epoch+1, num_epochs, d_loss.item(), g_loss.item()))
        
  ## AFTER EACH EPOCH##
  # append discriminator loss and generator loss
  losses.append((d_loss.item(), g_loss.item()))
  
  # generate and save sample, fake images
  G.eval() # eval mode for generating samples
  samples_z = G(fixed_z)
  samples.append(samples_z)
  G.train() # back to train mode

# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1558: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch [    1/  100] | d_loss: 1.3770 | g_loss: 0.7387
# Epoch [    1/  100] | d_loss: 1.2446 | g_loss: 1.4266
# Epoch [    1/  100] | d_loss: 1.2467 | g_loss: 1.6945
# Epoch [    2/  100] | d_loss: 1.2507 | g_loss: 0.8883
# Epoch [    2/  100] | d_loss: 1.2333 | g_loss: 0.8833
# Epoch [    2/  100] | d_loss: 1.3295 | g_loss: 2.3009
# Epoch [    3/  100] | d_loss: 0.8321 | g_loss: 3.2022
# Epoch [    3/  100] | d_loss: 1.0534 | g_loss: 1.4686
# Epoch [    3/  100] | d_loss: 0.9504 | g_loss: 1.3615
# Epoch [    4/  100] | d_loss: 0.9790 | g_loss: 2.3784
# Epoch [    4/  100] | d_loss: 0.8418 | g_loss: 2.8422
# Epoch [    4/  100] | d_loss: 1.5668 | g_loss: 0.9756
# Epoch [    5/  100] | d_loss: 1.2623 | g_loss: 1.3703
# Epoch [    5/  100] | d_loss: 1.1141 | g_loss: 1.7563
# Epoch [    5/  100] | d_loss: 1.3885 | g_loss: 1.0620
# Epoch [    6/  100] | d_loss: 1.1495 | g_loss: 1.1058
# Epoch [    6/  100] | d_loss: 1.1054 | g_loss: 1.4298
# Epoch [    6/  100] | d_loss: 1.2521 | g_loss: 0.9751
# Epoch [    7/  100] | d_loss: 1.3097 | g_loss: 1.1191
# Epoch [    7/  100] | d_loss: 1.0262 | g_loss: 1.4185
# Epoch [    7/  100] | d_loss: 1.3166 | g_loss: 0.9032
# Epoch [    8/  100] | d_loss: 1.6246 | g_loss: 1.1250
# Epoch [    8/  100] | d_loss: 1.0971 | g_loss: 1.6389
# Epoch [    8/  100] | d_loss: 1.3150 | g_loss: 0.9454
# Epoch [    9/  100] | d_loss: 1.1063 | g_loss: 1.8573
# Epoch [    9/  100] | d_loss: 1.2496 | g_loss: 1.2366
# Epoch [    9/  100] | d_loss: 1.1339 | g_loss: 1.3772
# Epoch [   10/  100] | d_loss: 1.3608 | g_loss: 1.3271
# Epoch [   10/  100] | d_loss: 1.3189 | g_loss: 0.9668
# Epoch [   10/  100] | d_loss: 1.3437 | g_loss: 0.9766
# Epoch [   11/  100] | d_loss: 1.3195 | g_loss: 0.8634
# Epoch [   11/  100] | d_loss: 1.1694 | g_loss: 1.2860
# Epoch [   11/  100] | d_loss: 1.3319 | g_loss: 1.0336
# Epoch [   12/  100] | d_loss: 1.3708 | g_loss: 1.1038
# Epoch [   12/  100] | d_loss: 1.2230 | g_loss: 1.3151
# Epoch [   12/  100] | d_loss: 1.1959 | g_loss: 0.9608
# Epoch [   13/  100] | d_loss: 1.2951 | g_loss: 0.8192
# Epoch [   13/  100] | d_loss: 1.1701 | g_loss: 1.1745
# Epoch [   13/  100] | d_loss: 1.3284 | g_loss: 1.1882
# Epoch [   14/  100] | d_loss: 1.2252 | g_loss: 1.0498
# Epoch [   14/  100] | d_loss: 1.2265 | g_loss: 1.1322
# Epoch [   14/  100] | d_loss: 1.2945 | g_loss: 1.0123
# Epoch [   15/  100] | d_loss: 1.3146 | g_loss: 1.1251
# Epoch [   15/  100] | d_loss: 1.1820 | g_loss: 1.0053
# Epoch [   15/  100] | d_loss: 1.2510 | g_loss: 0.9904
# Epoch [   16/  100] | d_loss: 1.1362 | g_loss: 1.3928
# Epoch [   16/  100] | d_loss: 1.1691 | g_loss: 1.5559
# Epoch [   16/  100] | d_loss: 1.3174 | g_loss: 0.9243
# Epoch [   17/  100] | d_loss: 1.3557 | g_loss: 1.1393
# Epoch [   17/  100] | d_loss: 1.3082 | g_loss: 1.0003
# Epoch [   17/  100] | d_loss: 1.3497 | g_loss: 1.1316
# Epoch [   18/  100] | d_loss: 1.2718 | g_loss: 1.3934
# Epoch [   18/  100] | d_loss: 1.3190 | g_loss: 0.9815
# Epoch [   18/  100] | d_loss: 1.3111 | g_loss: 0.9277
# Epoch [   19/  100] | d_loss: 1.3287 | g_loss: 0.8955
# Epoch [   19/  100] | d_loss: 1.2340 | g_loss: 1.0963
# Epoch [   19/  100] | d_loss: 1.3155 | g_loss: 1.3254
# Epoch [   20/  100] | d_loss: 1.2839 | g_loss: 0.9628
# Epoch [   20/  100] | d_loss: 1.3556 | g_loss: 0.8754
# Epoch [   20/  100] | d_loss: 1.3654 | g_loss: 1.1124
# Epoch [   21/  100] | d_loss: 1.3264 | g_loss: 1.0704
# Epoch [   21/  100] | d_loss: 1.2403 | g_loss: 1.6271
# Epoch [   21/  100] | d_loss: 1.2692 | g_loss: 1.0426
# Epoch [   22/  100] | d_loss: 1.2745 | g_loss: 0.9497
# Epoch [   22/  100] | d_loss: 1.3185 | g_loss: 1.3987
# Epoch [   22/  100] | d_loss: 1.2992 | g_loss: 1.1473
# Epoch [   23/  100] | d_loss: 1.1982 | g_loss: 1.2432
# Epoch [   23/  100] | d_loss: 1.2515 | g_loss: 1.0532
# Epoch [   23/  100] | d_loss: 1.3011 | g_loss: 0.9725
# Epoch [   24/  100] | d_loss: 1.2632 | g_loss: 1.2736
# Epoch [   24/  100] | d_loss: 1.2154 | g_loss: 0.9059
# Epoch [   24/  100] | d_loss: 1.3210 | g_loss: 0.9514
# Epoch [   25/  100] | d_loss: 1.3057 | g_loss: 0.9553
# Epoch [   25/  100] | d_loss: 1.1983 | g_loss: 1.2798
# Epoch [   25/  100] | d_loss: 1.3124 | g_loss: 0.8976
# Epoch [   26/  100] | d_loss: 1.2342 | g_loss: 1.0575
# Epoch [   26/  100] | d_loss: 1.2507 | g_loss: 1.0577
# Epoch [   26/  100] | d_loss: 1.2017 | g_loss: 1.6406
# Epoch [   27/  100] | d_loss: 1.4371 | g_loss: 0.8212
# Epoch [   27/  100] | d_loss: 1.3303 | g_loss: 1.3444
# Epoch [   27/  100] | d_loss: 1.4229 | g_loss: 1.0027
# Epoch [   28/  100] | d_loss: 1.3330 | g_loss: 0.9428
# Epoch [   28/  100] | d_loss: 1.3540 | g_loss: 0.9960
# Epoch [   28/  100] | d_loss: 1.2489 | g_loss: 0.9551
# Epoch [   29/  100] | d_loss: 1.3479 | g_loss: 0.9842
# Epoch [   29/  100] | d_loss: 1.3448 | g_loss: 0.9241
# Epoch [   29/  100] | d_loss: 1.1557 | g_loss: 1.4582
# Epoch [   30/  100] | d_loss: 1.1604 | g_loss: 1.2585
# Epoch [   30/  100] | d_loss: 1.2923 | g_loss: 1.0673
# Epoch [   30/  100] | d_loss: 1.3006 | g_loss: 0.9685
# Epoch [   31/  100] | d_loss: 1.2709 | g_loss: 1.4763
# Epoch [   31/  100] | d_loss: 1.1624 | g_loss: 1.1103
# Epoch [   31/  100] | d_loss: 1.2436 | g_loss: 1.0233
# Epoch [   32/  100] | d_loss: 1.3472 | g_loss: 1.1661
# Epoch [   32/  100] | d_loss: 1.2167 | g_loss: 1.3514
# Epoch [   32/  100] | d_loss: 1.3754 | g_loss: 0.9448
# Epoch [   33/  100] | d_loss: 1.3206 | g_loss: 0.9352
# Epoch [   33/  100] | d_loss: 1.2175 | g_loss: 0.9489
# Epoch [   33/  100] | d_loss: 1.3978 | g_loss: 1.0182
# Epoch [   34/  100] | d_loss: 1.2600 | g_loss: 0.8868
# Epoch [   34/  100] | d_loss: 1.2796 | g_loss: 1.1923
# Epoch [   34/  100] | d_loss: 1.3734 | g_loss: 1.1523
# Epoch [   35/  100] | d_loss: 1.2889 | g_loss: 0.9821
# Epoch [   35/  100] | d_loss: 1.3535 | g_loss: 1.0105
# Epoch [   35/  100] | d_loss: 1.4424 | g_loss: 1.1075
# Epoch [   36/  100] | d_loss: 1.3683 | g_loss: 1.2512
# Epoch [   36/  100] | d_loss: 1.1355 | g_loss: 1.1576
# Epoch [   36/  100] | d_loss: 1.3420 | g_loss: 1.2137
# Epoch [   37/  100] | d_loss: 1.3044 | g_loss: 0.7785
# Epoch [   37/  100] | d_loss: 1.2147 | g_loss: 1.0359
# Epoch [   37/  100] | d_loss: 1.2674 | g_loss: 0.8686
# Epoch [   38/  100] | d_loss: 1.3308 | g_loss: 0.8631
# Epoch [   38/  100] | d_loss: 1.3236 | g_loss: 0.8082
# Epoch [   38/  100] | d_loss: 1.3342 | g_loss: 0.8548
# Epoch [   39/  100] | d_loss: 1.2688 | g_loss: 0.9741
# Epoch [   39/  100] | d_loss: 1.3665 | g_loss: 1.0341
# Epoch [   39/  100] | d_loss: 1.4153 | g_loss: 0.8832
# Epoch [   40/  100] | d_loss: 1.2671 | g_loss: 0.9349
# Epoch [   40/  100] | d_loss: 1.2394 | g_loss: 1.1111
# Epoch [   40/  100] | d_loss: 1.3343 | g_loss: 0.8948
# Epoch [   41/  100] | d_loss: 1.2614 | g_loss: 1.0141
# Epoch [   41/  100] | d_loss: 1.2920 | g_loss: 1.1737
# Epoch [   41/  100] | d_loss: 1.2876 | g_loss: 0.9417
# Epoch [   42/  100] | d_loss: 1.3901 | g_loss: 1.0016
# Epoch [   42/  100] | d_loss: 1.3189 | g_loss: 1.0769
# Epoch [   42/  100] | d_loss: 1.3130 | g_loss: 1.0371
# Epoch [   43/  100] | d_loss: 1.2858 | g_loss: 0.9171
# Epoch [   43/  100] | d_loss: 1.3344 | g_loss: 1.0500
# Epoch [   43/  100] | d_loss: 1.4539 | g_loss: 1.3062
# Epoch [   44/  100] | d_loss: 1.3825 | g_loss: 0.8227
# Epoch [   44/  100] | d_loss: 1.3106 | g_loss: 0.9107
# Epoch [   44/  100] | d_loss: 1.2804 | g_loss: 1.0828
# Epoch [   45/  100] | d_loss: 1.2691 | g_loss: 0.9139
# Epoch [   45/  100] | d_loss: 1.2972 | g_loss: 0.9052
# Epoch [   45/  100] | d_loss: 1.3936 | g_loss: 1.0679
# Epoch [   46/  100] | d_loss: 1.3434 | g_loss: 0.9551
# Epoch [   46/  100] | d_loss: 1.1878 | g_loss: 0.8066
# Epoch [   46/  100] | d_loss: 1.3040 | g_loss: 1.0614
# Epoch [   47/  100] | d_loss: 1.2954 | g_loss: 0.8608
# Epoch [   47/  100] | d_loss: 1.3344 | g_loss: 0.9526
# Epoch [   47/  100] | d_loss: 1.3093 | g_loss: 0.9694
# Epoch [   48/  100] | d_loss: 1.3044 | g_loss: 0.7846
# Epoch [   48/  100] | d_loss: 1.2546 | g_loss: 0.9760
# Epoch [   48/  100] | d_loss: 1.3659 | g_loss: 0.9567
# Epoch [   49/  100] | d_loss: 1.1790 | g_loss: 1.2079
# Epoch [   49/  100] | d_loss: 1.2157 | g_loss: 1.3944
# Epoch [   49/  100] | d_loss: 1.2054 | g_loss: 1.0185
# Epoch [   50/  100] | d_loss: 1.2872 | g_loss: 0.7315
# Epoch [   50/  100] | d_loss: 1.2367 | g_loss: 0.9587
# Epoch [   50/  100] | d_loss: 1.3773 | g_loss: 0.9098
# Epoch [   51/  100] | d_loss: 1.3536 | g_loss: 1.0602
# Epoch [   51/  100] | d_loss: 1.3322 | g_loss: 0.8300
# Epoch [   51/  100] | d_loss: 1.3524 | g_loss: 1.0875
# Epoch [   52/  100] | d_loss: 1.3381 | g_loss: 0.9837
# Epoch [   52/  100] | d_loss: 1.2688 | g_loss: 1.0880
# Epoch [   52/  100] | d_loss: 1.2427 | g_loss: 1.0879
# Epoch [   53/  100] | d_loss: 1.2262 | g_loss: 1.1566
# Epoch [   53/  100] | d_loss: 1.2665 | g_loss: 1.0675
# Epoch [   53/  100] | d_loss: 1.3357 | g_loss: 0.9729
# Epoch [   54/  100] | d_loss: 1.2802 | g_loss: 1.0388
# Epoch [   54/  100] | d_loss: 1.2663 | g_loss: 0.9754
# Epoch [   54/  100] | d_loss: 1.4355 | g_loss: 1.1993
# Epoch [   55/  100] | d_loss: 1.3667 | g_loss: 1.0180
# Epoch [   55/  100] | d_loss: 1.2799 | g_loss: 0.9503
# Epoch [   55/  100] | d_loss: 1.3426 | g_loss: 0.9732
# Epoch [   56/  100] | d_loss: 1.2427 | g_loss: 0.9664
# Epoch [   56/  100] | d_loss: 1.1848 | g_loss: 0.8891
# Epoch [   56/  100] | d_loss: 1.3623 | g_loss: 1.0982
# Epoch [   57/  100] | d_loss: 1.2764 | g_loss: 0.8737
# Epoch [   57/  100] | d_loss: 1.3152 | g_loss: 1.0702
# Epoch [   57/  100] | d_loss: 1.3894 | g_loss: 1.0939
# Epoch [   58/  100] | d_loss: 1.3049 | g_loss: 1.0388
# Epoch [   58/  100] | d_loss: 1.2272 | g_loss: 1.2318
# Epoch [   58/  100] | d_loss: 1.3235 | g_loss: 1.0286
# Epoch [   59/  100] | d_loss: 1.2608 | g_loss: 1.0737
# Epoch [   59/  100] | d_loss: 1.2295 | g_loss: 0.9102
# Epoch [   59/  100] | d_loss: 1.2481 | g_loss: 0.8775
# Epoch [   60/  100] | d_loss: 1.2306 | g_loss: 1.4402
# Epoch [   60/  100] | d_loss: 1.2452 | g_loss: 1.0396
# Epoch [   60/  100] | d_loss: 1.3661 | g_loss: 1.1925
# Epoch [   61/  100] | d_loss: 1.2236 | g_loss: 1.4468
# Epoch [   61/  100] | d_loss: 1.2134 | g_loss: 1.0036
# Epoch [   61/  100] | d_loss: 1.3122 | g_loss: 1.0812
# Epoch [   62/  100] | d_loss: 1.4506 | g_loss: 1.3661
# Epoch [   62/  100] | d_loss: 1.1826 | g_loss: 1.0984
# Epoch [   62/  100] | d_loss: 1.3008 | g_loss: 1.0498
# Epoch [   63/  100] | d_loss: 1.3044 | g_loss: 0.7679
# Epoch [   63/  100] | d_loss: 1.2358 | g_loss: 1.0570
# Epoch [   63/  100] | d_loss: 1.3072 | g_loss: 1.1830
# Epoch [   64/  100] | d_loss: 1.3019 | g_loss: 1.6286
# Epoch [   64/  100] | d_loss: 1.3081 | g_loss: 0.9885
# Epoch [   64/  100] | d_loss: 1.3562 | g_loss: 1.0987
# Epoch [   65/  100] | d_loss: 1.2323 | g_loss: 1.4309
# Epoch [   65/  100] | d_loss: 1.2648 | g_loss: 1.0136
# Epoch [   65/  100] | d_loss: 1.2679 | g_loss: 1.0068
# Epoch [   66/  100] | d_loss: 1.2313 | g_loss: 1.1626
# Epoch [   66/  100] | d_loss: 1.3198 | g_loss: 1.0078
# Epoch [   66/  100] | d_loss: 1.3587 | g_loss: 0.9373
# Epoch [   67/  100] | d_loss: 1.2395 | g_loss: 1.4949
# Epoch [   67/  100] | d_loss: 1.2693 | g_loss: 1.2662
# Epoch [   67/  100] | d_loss: 1.3081 | g_loss: 1.0277
# Epoch [   68/  100] | d_loss: 1.2669 | g_loss: 1.1015
# Epoch [   68/  100] | d_loss: 1.3468 | g_loss: 1.0781
# Epoch [   68/  100] | d_loss: 1.2440 | g_loss: 1.1587
# Epoch [   69/  100] | d_loss: 1.2791 | g_loss: 0.9488
# Epoch [   69/  100] | d_loss: 1.2100 | g_loss: 0.9950
# Epoch [   69/  100] | d_loss: 1.4469 | g_loss: 0.8985
# Epoch [   70/  100] | d_loss: 1.1735 | g_loss: 1.0460
# Epoch [   70/  100] | d_loss: 1.2904 | g_loss: 0.9366
# Epoch [   70/  100] | d_loss: 1.2420 | g_loss: 1.0261
# Epoch [   71/  100] | d_loss: 1.2778 | g_loss: 0.8629
# Epoch [   71/  100] | d_loss: 1.2800 | g_loss: 1.0485
# Epoch [   71/  100] | d_loss: 1.3424 | g_loss: 1.0042
# Epoch [   72/  100] | d_loss: 1.1356 | g_loss: 1.0839
# Epoch [   72/  100] | d_loss: 1.2068 | g_loss: 0.8882
# Epoch [   72/  100] | d_loss: 1.2908 | g_loss: 1.1119
# Epoch [   73/  100] | d_loss: 1.3350 | g_loss: 1.0150
# Epoch [   73/  100] | d_loss: 1.2699 | g_loss: 1.2330
# Epoch [   73/  100] | d_loss: 1.3812 | g_loss: 0.8731
# Epoch [   74/  100] | d_loss: 1.3546 | g_loss: 1.1816
# Epoch [   74/  100] | d_loss: 1.1927 | g_loss: 0.9534
# Epoch [   74/  100] | d_loss: 1.3492 | g_loss: 0.9686
# Epoch [   75/  100] | d_loss: 1.2741 | g_loss: 0.7934
# Epoch [   75/  100] | d_loss: 1.1580 | g_loss: 1.1754
# Epoch [   75/  100] | d_loss: 1.3499 | g_loss: 1.0527
# Epoch [   76/  100] | d_loss: 1.2948 | g_loss: 1.2085
# Epoch [   76/  100] | d_loss: 1.2697 | g_loss: 0.9755
# Epoch [   76/  100] | d_loss: 1.3159 | g_loss: 0.8822
# Epoch [   77/  100] | d_loss: 1.3375 | g_loss: 1.0565
# Epoch [   77/  100] | d_loss: 1.1735 | g_loss: 1.0375
# Epoch [   77/  100] | d_loss: 1.2901 | g_loss: 0.9229
# Epoch [   78/  100] | d_loss: 1.2570 | g_loss: 1.0133
# Epoch [   78/  100] | d_loss: 1.2394 | g_loss: 1.3983
# Epoch [   78/  100] | d_loss: 1.3425 | g_loss: 1.1412
# Epoch [   79/  100] | d_loss: 1.2209 | g_loss: 1.0271
# Epoch [   79/  100] | d_loss: 1.2841 | g_loss: 0.8800
# Epoch [   79/  100] | d_loss: 1.3135 | g_loss: 0.9837
# Epoch [   80/  100] | d_loss: 1.2867 | g_loss: 1.0265
# Epoch [   80/  100] | d_loss: 1.2536 | g_loss: 1.2402
# Epoch [   80/  100] | d_loss: 1.2441 | g_loss: 1.0429
# Epoch [   81/  100] | d_loss: 1.2993 | g_loss: 0.9198
# Epoch [   81/  100] | d_loss: 1.2112 | g_loss: 1.2310
# Epoch [   81/  100] | d_loss: 1.4401 | g_loss: 1.2176
# Epoch [   82/  100] | d_loss: 1.2475 | g_loss: 1.1849
# Epoch [   82/  100] | d_loss: 1.2563 | g_loss: 1.0709
# Epoch [   82/  100] | d_loss: 1.3431 | g_loss: 0.9465
# Epoch [   83/  100] | d_loss: 1.2266 | g_loss: 1.1590
# Epoch [   83/  100] | d_loss: 1.2514 | g_loss: 1.1445
# Epoch [   83/  100] | d_loss: 1.1889 | g_loss: 0.9714
# Epoch [   84/  100] | d_loss: 1.3649 | g_loss: 1.3901
# Epoch [   84/  100] | d_loss: 1.3586 | g_loss: 1.2324
# Epoch [   84/  100] | d_loss: 1.1462 | g_loss: 1.1891
# Epoch [   85/  100] | d_loss: 1.2549 | g_loss: 0.9144
# Epoch [   85/  100] | d_loss: 1.3076 | g_loss: 1.0490
# Epoch [   85/  100] | d_loss: 1.4222 | g_loss: 1.1420
# Epoch [   86/  100] | d_loss: 1.2807 | g_loss: 1.0326
# Epoch [   86/  100] | d_loss: 1.3209 | g_loss: 1.1359
# Epoch [   86/  100] | d_loss: 1.3880 | g_loss: 1.2494
# Epoch [   87/  100] | d_loss: 1.1364 | g_loss: 1.2790
# Epoch [   87/  100] | d_loss: 1.3316 | g_loss: 0.9724
# Epoch [   87/  100] | d_loss: 1.3349 | g_loss: 0.9771
# Epoch [   88/  100] | d_loss: 1.2293 | g_loss: 1.0575
# Epoch [   88/  100] | d_loss: 1.2664 | g_loss: 1.0330
# Epoch [   88/  100] | d_loss: 1.2443 | g_loss: 1.2002
# Epoch [   89/  100] | d_loss: 1.2742 | g_loss: 0.9676
# Epoch [   89/  100] | d_loss: 1.2235 | g_loss: 0.9853
# Epoch [   89/  100] | d_loss: 1.3311 | g_loss: 0.9431
# Epoch [   90/  100] | d_loss: 1.2626 | g_loss: 1.0647
# Epoch [   90/  100] | d_loss: 1.2158 | g_loss: 0.9486
# Epoch [   90/  100] | d_loss: 1.3580 | g_loss: 1.0775
# Epoch [   91/  100] | d_loss: 1.3136 | g_loss: 1.5087
# Epoch [   91/  100] | d_loss: 1.3317 | g_loss: 1.0655
# Epoch [   91/  100] | d_loss: 1.2923 | g_loss: 1.1528
# Epoch [   92/  100] | d_loss: 1.3248 | g_loss: 0.9430
# Epoch [   92/  100] | d_loss: 1.2407 | g_loss: 1.0579
# Epoch [   92/  100] | d_loss: 1.3643 | g_loss: 1.1332
# Epoch [   93/  100] | d_loss: 1.2713 | g_loss: 1.1521
# Epoch [   93/  100] | d_loss: 1.2843 | g_loss: 0.9567
# Epoch [   93/  100] | d_loss: 1.2912 | g_loss: 1.1868
# Epoch [   94/  100] | d_loss: 1.3195 | g_loss: 1.6695
# Epoch [   94/  100] | d_loss: 1.2718 | g_loss: 1.0425
# Epoch [   94/  100] | d_loss: 1.3605 | g_loss: 1.0299
# Epoch [   95/  100] | d_loss: 1.3521 | g_loss: 1.0099
# Epoch [   95/  100] | d_loss: 1.1646 | g_loss: 1.7876
# Epoch [   95/  100] | d_loss: 1.1797 | g_loss: 1.1894
# Epoch [   96/  100] | d_loss: 1.2123 | g_loss: 1.1005
# Epoch [   96/  100] | d_loss: 1.1450 | g_loss: 1.2011
# Epoch [   96/  100] | d_loss: 1.5442 | g_loss: 1.1282
# Epoch [   97/  100] | d_loss: 1.2220 | g_loss: 1.1329
# Epoch [   97/  100] | d_loss: 1.2192 | g_loss: 1.1178
# Epoch [   97/  100] | d_loss: 1.3584 | g_loss: 1.0129
# Epoch [   98/  100] | d_loss: 1.1697 | g_loss: 1.1851
# Epoch [   98/  100] | d_loss: 1.2420 | g_loss: 1.0364
# Epoch [   98/  100] | d_loss: 1.2721 | g_loss: 0.9531
# Epoch [   99/  100] | d_loss: 1.2519 | g_loss: 0.9747
# Epoch [   99/  100] | d_loss: 1.2296 | g_loss: 1.0353
# Epoch [   99/  100] | d_loss: 1.2749 | g_loss: 1.1262
# Epoch [  100/  100] | d_loss: 1.2088 | g_loss: 1.1082
# Epoch [  100/  100] | d_loss: 1.2509 | g_loss: 0.9759
# Epoch [  100/  100] | d_loss: 1.3629 | g_loss: 1.1553
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %% [markdown]
# # **Training loss**

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# # **Generator samples from training**

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
# -1 indicates final epoch's samples (the last in the list)
view_samples(-1, samples)

# %%
rows = 10 # split epochs into 10, so 100/10 = every 10 epochs
cols = 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        img = img.detach()
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# # **Sampling from the generator**

# %%
# randomly generated, new latent vectors
sample_size=16
rand_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
rand_z = torch.from_numpy(rand_z).float()

G.eval() # eval mode
# generated samples
rand_images = G(rand_z)

# 0 indicates the first set of samples in the passed in list
# and we only have one batch of samples, here
view_samples(0, [rand_images])
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1558: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
